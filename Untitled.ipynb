# %%
def create_dataset(n_samples, m, c):
    # create the sample dataset
    x = np.random.normal(mean, std, n_samples)
    random_noise = np.random.normal(mean, std, n_samples)
    y = m*x + c + random_noise
    x_train, y_train = x[:8000], y[:8000]
    x_test, y_test = x[8000:], y[8000:]
    return x_train, y_train, x_test, y_test

# %%
def pred(x, W, B):
    """
    calculate y_hat = m*x + c with learned weights and biases.
    y_hat is the prediction
    """
    y_hat = W*x + B
    return y_hat

# %%
def calculate_gradient(x, y, W, B):
    """
    Calculate the derivative of the loss
    """
    with tf.GradientTape() as tape:
        loss_value = loss(x, y, W, B)
        
    w_grad, b_grad = tape.gradient(loss_value, [W, B])
    return w_grad, b_grad

# %%
def loss(x, y, W, B):
    """
    Mean squared error loss function
    """
    prediction = pred(x, W, B)
    squared_error = tf.square(prediction - y)
    # finally calculate the MSE (Mean Sqaured Error)
    mse = tf.reduce_mean(squared_error)
    return mse

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# number of training samples to create
n_samples = 10000
# `m` and `c` are coefficient and bias to get the initial `y`
m = 9
c = -2
mean = 0.0 # mean of the training data distribution to create
std = 1.0 # standard deviation of the of the training data distribution to create
# number of training epochs 
num_epochs = 3000
# learning rate
learning_rate = 0.001

# %%
x_train, y_train, x_test, y_test = create_dataset(n_samples, m, c)
print(f"Training samples: {len(x_train)}")
print(f"Test samples: {len(x_test)}")
plt.figure(figsize=(12, 9))
plt.scatter(x_train, y_train)
plt.xlabel('x_train')
plt.ylabel('y_train')
plt.title('Training data distribution')
plt.savefig('training_data.jpg')
# Out:
# Training samples: 8000
# Test samples: 2000

# %%
# random initial values for weights
W = tf.Variable(np.random.randn())
B = tf.Variable(np.random.randn())
print(W)
print(B)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=-1.3793874>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=-0.20214686>

# %%
for epoch in range(num_epochs):
    w_grad, b_grad = calculate_gradient(x_train, y_train, W, B)
    
    dW, dB = w_grad * learning_rate, b_grad * learning_rate
    
    W.assign_sub(dW)
    B.assign_sub(dB)
    
    if epoch % 10 == 0:
        print(f"Epoch: {epoch}, loss {loss(x_train, y_train, W, B):.3f}")
# Out:
# Epoch: 0, loss 110.073
# Epoch: 10, loss 105.839
# Epoch: 20, loss 101.768
# Epoch: 30, loss 97.856
# Epoch: 40, loss 94.096
# Epoch: 50, loss 90.481
# Epoch: 60, loss 87.007
# Epoch: 70, loss 83.668
# Epoch: 80, loss 80.458
# Epoch: 90, loss 77.373
# Epoch: 100, loss 74.408
# Epoch: 110, loss 71.557
# Epoch: 120, loss 68.818
# Epoch: 130, loss 66.185
# Epoch: 140, loss 63.654
# Epoch: 150, loss 61.221
# Epoch: 160, loss 58.883
# Epoch: 170, loss 56.635
# Epoch: 180, loss 54.475
# Epoch: 190, loss 52.399
# Epoch: 200, loss 50.403
# Epoch: 210, loss 48.484
# Epoch: 220, loss 46.641
# Epoch: 230, loss 44.868
# Epoch: 240, loss 43.165
# Epoch: 250, loss 41.527
# Epoch: 260, loss 39.954
# Epoch: 270, loss 38.441
# Epoch: 280, loss 36.987
# Epoch: 290, loss 35.590
# Epoch: 300, loss 34.246
# Epoch: 310, loss 32.955
# Epoch: 320, loss 31.714
# Epoch: 330, loss 30.521
# Epoch: 340, loss 29.375
# Epoch: 350, loss 28.273
# Epoch: 360, loss 27.214
# Epoch: 370, loss 26.195
# Epoch: 380, loss 25.217
# Epoch: 390, loss 24.276
# Epoch: 400, loss 23.372
# Epoch: 410, loss 22.503
# Epoch: 420, loss 21.668
# Epoch: 430, loss 20.865
# Epoch: 440, loss 20.093
# Epoch: 450, loss 19.352
# Epoch: 460, loss 18.639
# Epoch: 470, loss 17.954
# Epoch: 480, loss 17.295
# Epoch: 490, loss 16.662
# Epoch: 500, loss 16.053
# Epoch: 510, loss 15.468
# Epoch: 520, loss 14.906
# Epoch: 530, loss 14.366
# Epoch: 540, loss 13.847
# Epoch: 550, loss 13.347
# Epoch: 560, loss 12.868
# Epoch: 570, loss 12.406
# Epoch: 580, loss 11.963
# Epoch: 590, loss 11.537
# Epoch: 600, loss 11.127
# Epoch: 610, loss 10.734
# Epoch: 620, loss 10.355
# Epoch: 630, loss 9.992
# Epoch: 640, loss 9.642
# Epoch: 650, loss 9.306
# Epoch: 660, loss 8.983
# Epoch: 670, loss 8.673
# Epoch: 680, loss 8.374
# Epoch: 690, loss 8.088
# Epoch: 700, loss 7.812
# Epoch: 710, loss 7.547
# Epoch: 720, loss 7.292
# Epoch: 730, loss 7.048
# Epoch: 740, loss 6.812
# Epoch: 750, loss 6.586
# Epoch: 760, loss 6.369
# Epoch: 770, loss 6.160
# Epoch: 780, loss 5.959
# Epoch: 790, loss 5.766
# Epoch: 800, loss 5.580
# Epoch: 810, loss 5.402
# Epoch: 820, loss 5.231
# Epoch: 830, loss 5.066
# Epoch: 840, loss 4.908
# Epoch: 850, loss 4.755
# Epoch: 860, loss 4.609
# Epoch: 870, loss 4.469
# Epoch: 880, loss 4.333
# Epoch: 890, loss 4.203
# Epoch: 900, loss 4.079
# Epoch: 910, loss 3.959
# Epoch: 920, loss 3.843
# Epoch: 930, loss 3.732
# Epoch: 940, loss 3.626
# Epoch: 950, loss 3.523
# Epoch: 960, loss 3.425
# Epoch: 970, loss 3.330
# Epoch: 980, loss 3.239
# Epoch: 990, loss 3.152
# Epoch: 1000, loss 3.068
# Epoch: 1010, loss 2.987
# Epoch: 1020, loss 2.909
# Epoch: 1030, loss 2.835
# Epoch: 1040, loss 2.763
# Epoch: 1050, loss 2.694
# Epoch: 1060, loss 2.628
# Epoch: 1070, loss 2.564
# Epoch: 1080, loss 2.503
# Epoch: 1090, loss 2.444
# Epoch: 1100, loss 2.387
# Epoch: 1110, loss 2.333
# Epoch: 1120, loss 2.281
# Epoch: 1130, loss 2.231
# Epoch: 1140, loss 2.182
# Epoch: 1150, loss 2.136
# Epoch: 1160, loss 2.091
# Epoch: 1170, loss 2.048
# Epoch: 1180, loss 2.007
# Epoch: 1190, loss 1.968
# Epoch: 1200, loss 1.929
# Epoch: 1210, loss 1.893
# Epoch: 1220, loss 1.858
# Epoch: 1230, loss 1.824
# Epoch: 1240, loss 1.791
# Epoch: 1250, loss 1.760
# Epoch: 1260, loss 1.730
# Epoch: 1270, loss 1.701
# Epoch: 1280, loss 1.674
# Epoch: 1290, loss 1.647
# Epoch: 1300, loss 1.621
# Epoch: 2240, loss 1.002
# Epoch: 2250, loss 1.002
# Epoch: 2260, loss 1.001
# Epoch: 2270, loss 1.000
# Epoch: 2280, loss 1.000
# Epoch: 2290, loss 0.999
# Epoch: 2300, loss 0.999
# Epoch: 2310, loss 0.998
# Epoch: 2320, loss 0.998
# Epoch: 2330, loss 0.998
# Epoch: 2340, loss 0.997
# Epoch: 2350, loss 0.997
# Epoch: 2360, loss 0.996
# Epoch: 2370, loss 0.996
# Epoch: 2380, loss 0.996
# Epoch: 2390, loss 0.995
# Epoch: 2400, loss 0.995
# Epoch: 2410, loss 0.995
# Epoch: 2420, loss 0.994
# Epoch: 2430, loss 0.994
# Epoch: 2440, loss 0.994
# Epoch: 2450, loss 0.993
# Epoch: 2460, loss 0.993
# Epoch: 2470, loss 0.993
# Epoch: 2480, loss 0.993
# Epoch: 2490, loss 0.992
# Epoch: 2500, loss 0.992
# Epoch: 2510, loss 0.992
# Epoch: 2520, loss 0.992
# Epoch: 2530, loss 0.992
# Epoch: 2540, loss 0.991
# Epoch: 2550, loss 0.991
# Epoch: 2560, loss 0.991
# Epoch: 2570, loss 0.991
# Epoch: 2580, loss 0.991
# Epoch: 2590, loss 0.991
# Epoch: 2600, loss 0.990
# Epoch: 2610, loss 0.990
# Epoch: 2620, loss 0.990
# Epoch: 2630, loss 0.990
# Epoch: 2640, loss 0.990
# Epoch: 2650, loss 0.990
# Epoch: 2660, loss 0.990
# Epoch: 2670, loss 0.990
# Epoch: 2680, loss 0.989
# Epoch: 2690, loss 0.989
# Epoch: 2700, loss 0.989
# Epoch: 2710, loss 0.989
# Epoch: 2720, loss 0.989
# Epoch: 2730, loss 0.989
# Epoch: 2740, loss 0.989
# Epoch: 2750, loss 0.989
# Epoch: 2760, loss 0.989
# Epoch: 2770, loss 0.989
# Epoch: 2780, loss 0.989
# Epoch: 2790, loss 0.989
# Epoch: 2800, loss 0.988
# Epoch: 2810, loss 0.988
# Epoch: 2820, loss 0.988
# Epoch: 2830, loss 0.988
# Epoch: 2840, loss 0.988
# Epoch: 2850, loss 0.988
# Epoch: 2860, loss 0.988
# Epoch: 2870, loss 0.988
# Epoch: 2880, loss 0.988
# Epoch: 2890, loss 0.988
# Epoch: 2900, loss 0.988
# Epoch: 2910, loss 0.988
# Epoch: 2920, loss 0.988
# Epoch: 2930, loss 0.988
# Epoch: 2940, loss 0.988
# Epoch: 2950, loss 0.988
# Epoch: 2960, loss 0.988
# Epoch: 2970, loss 0.988
# Epoch: 2980, loss 0.988
# Epoch: 2990, loss 0.988

# %%
# check whether we get the desired `m` and `c` or not
print(f"Learned W: {W.numpy()}, learned B: {B.numpy()}")
# Out:
# Learned W: 8.96248722076416, learned B: -1.9956588745117188

# %%
# predicted y on on the test set
y_test_predicted = W.numpy()*x_test + B.numpy()
# plot the predicted y values on the test data distribution
plt.figure(figsize=(12, 9))
plt.plot(x_test, y_test_predicted, c='red')
plt.scatter(x_test, y_test)
plt.xlabel('x_test')
plt.ylabel('y_test')
plt.title('Test data distribution and predicted y plot')
# Out:
# Text(0.5, 1.0, 'Test data distribution and predicted y plot')
